# %% [markdown]
# #Bioacoustics AIMS 2025

# %% [markdown]
# #Instructions on how to use this notebook
# This notebook is hosted on ``Google Colab``. To be able to work on it, you have to create your own copy. Go to *File* and select *Save a copy in Drive*.
#
# You can also avoid using ``Colab`` entirely, and download the notebook to run it on your own machine. If you choose this, go to *File* and select *Download .ipynb*.

# %%
#Run this cell
# !pip install git+https://github.com/google-research/perch-hoplite.git
# Out:
# Collecting git+https://github.com/google-research/perch-hoplite.git
#   Cloning https://github.com/google-research/perch-hoplite.git to /tmp/pip-req-build-ptvaubxb
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/perch-hoplite.git /tmp/pip-req-build-ptvaubxb
#   Resolved https://github.com/google-research/perch-hoplite.git to commit b075df9dfe2eedbaebfd3e97a52b4cffe3569fe2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: absl-py<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (1.4.0)
# Requirement already satisfied: etils<2.0.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from etils[epath]<2.0.0,>=1.5.0->perch-hoplite==0.1.2) (1.13.0)
# Requirement already satisfied: imageio<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (2.37.2)
# Collecting ipywidgets<9.0,>=8.1 (from perch-hoplite==0.1.2)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: kagglehub<0.4,>=0.3 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (0.3.13)
# Requirement already satisfied: librosa<0.12,>=0.11 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (0.11.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.6.1 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (3.10.0)
# Collecting ml-collections<0.2.0,>=0.1.1 (from perch-hoplite==0.1.2)
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting notebook<8.0,>=7.4 (from perch-hoplite==0.1.2)
#   Downloading notebook-7.5.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.1,>=2.0 in /usr/local/lib/python3.12/dist-packages (from perch-hoplite==0.1.2) (2.0.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.2.2)
# Collecting usearch<3.0,>=2.17 (from perch-hoplite==0.1.2)
#   Downloading usearch-2.21.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]<2.0.0,>=1.5.0->perch-hoplite==0.1.2) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]<2.0.0,>=1.5.0->perch-hoplite==0.1.2) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]<2.0.0,>=1.5.0->perch-hoplite==0.1.2) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]<2.0.0,>=1.5.0->perch-hoplite==0.1.2) (3.23.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio<3.0.0,>=2.5.0->perch-hoplite==0.1.2) (11.3.0)
# Collecting comm>=0.1.3 (from ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (3.0.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa<0.12,>=0.11->perch-hoplite==0.1.2) (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.6.1->perch-hoplite==0.1.2) (2.9.0.post0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ml-collections<0.2.0,>=0.1.1->perch-hoplite==0.1.2) (1.17.0)
# Collecting contextlib2 (from ml-collections<0.2.0,>=0.1.1->perch-hoplite==0.1.2)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from notebook<8.0,>=7.4->perch-hoplite==0.1.2) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from notebook<8.0,>=7.4->perch-hoplite==0.1.2)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.6,>=4.5.0rc0 (from notebook<8.0,>=7.4->perch-hoplite==0.1.2)
#   Downloading jupyterlab-4.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.12/dist-packages (from notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from notebook<8.0,>=7.4->perch-hoplite==0.1.2) (6.5.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.1->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.1->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2025.2)
# Requirement already satisfied: gcsfs>=2022.11.0 in /usr/local/lib/python3.12/dist-packages (from pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2025.3.0)
# Requirement already satisfied: pandas-gbq>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (0.30.0)
# Requirement already satisfied: simsimd<7.0.0,>=6.0.5 in /usr/local/lib/python3.12/dist-packages (from usearch<3.0,>=2.17->perch-hoplite==0.1.2) (6.5.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (3.13.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (3.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (4.9.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.9.0)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (6.17.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (4.25.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa<0.12,>=0.11->perch-hoplite==0.1.2) (0.43.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.4.4)
# Requirement already satisfied: pyarrow>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (18.1.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.10.2 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.28.1)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (3.38.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa<0.12,>=0.11->perch-hoplite==0.1.2) (4.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub<0.4,>=0.3->perch-hoplite==0.1.2) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa<0.12,>=0.11->perch-hoplite==0.1.2) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa<0.12,>=0.11->perch-hoplite==0.1.2) (2.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.22.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (25.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa<0.12,>=0.11->perch-hoplite==0.1.2) (2.23)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.10.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.2->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (2.8.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.16.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.8.15)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.29.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets<9.0,>=8.1->perch-hoplite==0.1.2) (0.2.14)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.4.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.4.2->pandas-gbq>=0.19.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (1.71.2)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (25.10.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.11.0->pandas[gcp]<3.0.0,>=2.1.1->perch-hoplite==0.1.2) (3.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (2.8)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook<8.0,>=7.4->perch-hoplite==0.1.2) (1.4.0)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.8 MB/s eta 0:00:00
# Downloading notebook-7.5.0-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 61.5 MB/s eta 0:00:00
# Downloading usearch-2.21.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.5 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading jupyterlab-4.5.0-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 78.0 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.4 MB/s eta 0:00:00
# Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.9 MB/s eta 0:00:00
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: perch-hoplite, ml-collections
#   Building wheel for perch-hoplite (pyproject.toml) ... done
#   Created wheel for perch-hoplite: filename=perch_hoplite-0.1.2-py3-none-any.whl size=3755181 sha256=c5b560bef04b6bf1cf0374249ba04221907d98ac68d54732fa4d8ab466194a56
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hc_68gn2/wheels/fd/3e/2b/151315ad93fdac45847aea95f7738a3866237b2f944d0f44eb
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94507 sha256=0a6642aded4832931cb9d0c7f5c9518f174ddf817cf3b590636d79ed3b2264ed
#   Stored in directory: /root/.cache/pip/wheels/3e/53/7b/1a6f4bfa9dac09618feedc8b1f28a55d4ab9d4bb8835dc0b7e
# Successfully built perch-hoplite ml-collections
# Installing collected packages: widgetsnbextension, usearch, json5, jedi, contextlib2, comm, async-lru, ml-collections, ipywidgets, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, perch-hoplite
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.5.0 which is incompatible.
# Successfully installed async-lru-2.0.5 comm-0.2.3 contextlib2-21.6.0 ipywidgets-8.1.8 jedi-0.19.2 json5-0.12.1 jupyter-lsp-2.3.0 jupyterlab-4.5.0 jupyterlab-server-2.28.0 ml-collections-0.1.1 notebook-7.5.0 perch-hoplite-0.1.2 usearch-2.21.0 widgetsnbextension-4.0.15

# %% [markdown]
# # Building a Dataset
#
# We will be using [PowderMill Annotated Dataset](https://zenodo.org/records/4656848#.Y7ijhOxudhE) for this Lab. This dataset has been uploaded to Google Cloud Storage for easier access.

# %%
#Run this cell to load the Powdermill dataset and its annotations from Google Cloud Storage
from etils import epath
rec_path = epath.Path('gs://chirp-public-bucket/soundscapes/powdermill/Recording_2')
annos_path = epath.Path('gs://chirp-public-bucket/soundscapes/powdermill/powdermill.csv')

# These epath.Path objects let us interact with the files in Google Cloud
# Storage without having to download them first.

# Some useful methods+tricks:
for fp in rec_path.iterdir():
  pass
  # print(fp)

# Opening a file:
with annos_path.open() as f:
  # do stuff...
  pass

# Iterate over files ending in '.wav':
for fp in rec_path.glob('*.wav'):
  with fp.open() as f:
    pass
# Out:
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_01.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_01.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_02.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_02.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_03.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_03.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_04.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_04.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_05.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_05.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_06.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_06.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_07.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_07.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_08.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_08.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_09.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_09.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_10.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_10.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_11.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_11.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_12.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_12.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_13.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_13.wav
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_14.Table.1.selections.txt
# gs://chirp-public-bucket/soundscapes/powdermill/Recording_2/Recording_2_Segment_14.wav

# %%
#YOUR CODE GOES HERE
#Read and list all the wav files in the Recording Path

# %%
#YOUR CODE GOES HERE

  # (i) Open each file, create a spectrogram for every 5-second segment within each file.
  # (ii) Put all of the spectrograms in one big array.
  # (iii) Make a second list/dataframe with the source file and start and end time of each spectrogram.

# %%
import csv
import collections

#YOUR CODE GOES HERE

#(i) Read the annotations file and list all species

# %%
# Let's work with EATO, which is the Eastern Towhee.
eato_annos = []

#YOUR CODE GOES HERE

#(i) *** Create an array of EATO labels for each spectrogram in our big tensor.
#(ii) Check for overlapping annotations with each spectrogram segment:
#           anno_start < window_end AND anno_end > window_start

# %% [markdown]
# #Classification

# %%
#YOUR CODE GOES HERE

# Next, reduce the spectrograms to single vectors. (How many ways can you think of to do this?)
# Use sklearn.LogisticRegression to train a classifier over your reduced spectrograms.

# %%
#YOUR CODE GOES HERE

# The Powdermill dataset contains four Recordings (Recording_1, Recording_2, etc).
# Refactor your function for loading the spectrograms into an array and loads
# the labels into a function, which takes the Recording directory as input.

# Use the spectrograms and labels from the other Recordings to evaluate your model.
# Compute the ROC-AUC score:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
# (Note: it will proooobably be bad scores.)

# %%
#YOUR CODE GOES HERE

# Extension if you find yourself done early!
# Use T-SNE to reduce your 'single vectors' to two dimensions:
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
# Use matplot lib's `scatter` to plot the points, and color them according to
# the EATO label.

# If you finish this, shout!
